# %%
import pandas as pd

# %%
df = pd.read_csv("/home/aqua/Documents/Tugas Akhir/program/backend/uploads/sampled_1000_dataset.csv")
df = df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
df.head()
# Out:
#    Dst Port  Protocol  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# 0        80         6        5084352             4             4
# 1        80         6       56516055           153           104
# 2        22         6             19             1             1
# 3        80         6       56232107           153           104
# 4        80         6          20166             3             4
#
#    TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  Fwd Pkt Len Min  \
# 0              375              972              375                0
# 1            54995            72483              646                0
# 2                0                0                0                0
# 3            54995            72494              646                0
# 4              313              935              313                0
#
#    Fwd Pkt Len Mean  ...  Fwd Seg Size Min  Active Mean  Active Std  \
# 0         93.896860  ...                32          0.0         0.0
# ...

# %%
df['Label'].value_counts()
# Out:
# 3     104
# 4     103
# 10    100
# 8      98
# 6      93
# 2      89
# 7      87
# 1      84
# 5      83
# 11     80
# 9      79
# Name: Label, dtype: int64
